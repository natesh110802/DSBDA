# %%
# Importing pandas library
import pandas as pd

# %%
data = pd.read_csv("iris.csv")

# %%
data
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
iris.groupby('variety')['sepal.width'].agg(['min', 'max', 'mean', 'median', 'std'])
# Out:
#             min  max   mean  median       std
# variety
# Setosa      2.3  4.4  3.428     3.4  0.379064
# Versicolor  2.0  3.4  2.770     2.8  0.313798
# Virginica   2.2  3.8  2.974     3.0  0.322497

# %%
iris.groupby('variety')['sepal.length'].agg(['min', 'max', 'mean', 'median', 'std'])
# Out:
#             min  max   mean  median       std
# variety
# Setosa      4.3  5.8  5.006     5.0  0.352490
# Versicolor  4.9  7.0  5.936     5.9  0.516171
# Virginica   4.9  7.9  6.588     6.5  0.635880

# %%
iris.groupby('variety')['petal.length'].agg(['min', 'max', 'mean', 'median', 'std'])
# Out:
#             min  max   mean  median       std
# variety
# Setosa      1.0  1.9  1.462    1.50  0.173664
# Versicolor  3.0  5.1  4.260    4.35  0.469911
# Virginica   4.5  6.9  5.552    5.55  0.551895

# %%
iris.groupby('variety')['petal.width'].agg(['min', 'max', 'mean', 'median', 'std'])
# Out:
#             min  max   mean  median       std
# variety
# Setosa      0.1  0.6  0.246     0.2  0.105386
# Versicolor  1.0  1.8  1.326     1.3  0.197753
# Virginica   1.4  2.5  2.026     2.0  0.274650

# %%
iris.groupby('variety')['sepal.length'].agg(['min', 'max', 'mean', 'median', 'std', 'var'])
# Out:
#             min  max   mean  median       std       var
# variety
# Setosa      4.3  5.8  5.006     5.0  0.352490  0.124249
# Versicolor  4.9  7.0  5.936     5.9  0.516171  0.266433
# Virginica   4.9  7.9  6.588     6.5  0.635880  0.404343

# %%
iris.groupby('variety')['sepal.length'].min()
# Out:
# variety
# Setosa        4.3
# Versicolor    4.9
# Virginica     4.9
# Name: sepal.length, dtype: float64

# %%
iris.groupby('variety')['sepal.length'].max()
# Out:
# variety
# Setosa        5.8
# Versicolor    7.0
# Virginica     7.9
# Name: sepal.length, dtype: float64

# %%
iris.groupby('variety')['sepal.length'].mean()
# Out:
# variety
# Setosa        5.006
# Versicolor    5.936
# Virginica     6.588
# Name: sepal.length, dtype: float64

# %%
iris.groupby('variety')['sepal.length'].median()
# Out:
# variety
# Setosa        5.0
# Versicolor    5.9
# Virginica     6.5
# Name: sepal.length, dtype: float64

# %%
iris.groupby('variety')['sepal.length'].std()
# Out:
# variety
# Setosa        0.352490
# Versicolor    0.516171
# Virginica     0.635880
# Name: sepal.length, dtype: float64

# %%
iris.groupby('variety')['sepal.length'].var()
# Out:
# variety
# Setosa        0.124249
# Versicolor    0.266433
# Virginica     0.404343
# Name: sepal.length, dtype: float64

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as matp
# %matplotlib inline
